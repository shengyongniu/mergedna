# %% [markdown]
# # MergeDNA toy Colab
#
# This notebook runs the compact MergeDNA prototype on synthetic DNA. It is a smoke test and demo, not paper-scale pretraining.

# %%
# !git clone https://github.com/shengyongniu/mergedna.git || true
# %cd mergedna
# !pip install -e ".[dev,notebook]"

# %%
# !pytest

# %%
# !python scripts/train_toy.py --steps 100 --batch-size 16 --seq-len 256 --d-model 128 --device cuda --checkpoint checkpoints/toy.pt

# %%
# !python scripts/inspect_tokenization.py --checkpoint checkpoints/toy.pt
