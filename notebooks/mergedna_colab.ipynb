# %% [markdown]
# # MergeDNA toy Colab
#
# This notebook runs the compact MergeDNA prototype on synthetic DNA. It is a smoke test and demo, not paper-scale pretraining.

# %%
# !git clone https://github.com/shengyongniu/mergedna.git
# %cd mergedna
# Out:
# Cloning into 'mergedna'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 98 (delta 40), reused 96 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 401.76 KiB | 25.11 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/mergedna

# %%
# !pip install -e ".[dev,notebook]" -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 137.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 136.6 MB/s eta 0:00:00
#   Building editable for mergedna (pyproject.toml) ... done

# %%
# !mkdir -p data
# !curl -sS "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=nuccore&id=U00096.3&rettype=fasta_cds_na&retmode=text" -o data/ecoli_k12_cds.fa
# !ls -lh data/ecoli_k12_cds.fa
# Out:
# -rw-r--r-- 1 root root 4.8M May 18 07:54 data/ecoli_k12_cds.fa

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/mergedna
# configfile: pyproject.toml
# testpaths: tests
# plugins: anyio-4.13.0, langsmith-0.7.34, typeguard-4.5.1
# collected 19 items
#
# tests/test_data.py ....                                                  [ 21%]
# tests/test_losses.py ..                                                  [ 31%]
# tests/test_merge.py ......                                               [ 63%]
# tests/test_model.py .......                                              [100%]
#
# ============================== 19 passed in 5.23s ==============================

# %%
# !python scripts/train_toy.py --fasta data/ecoli_k12_cds.fa \
  --steps 1000 --batch-size 64 --seq-len 512 --d-model 128 \
  --lr 5e-4 --print-every 20 --device cuda \
  --checkpoint checkpoints/ecoli.pt
# Out:
# step 0020 total=137.1766 mtr=1.2943 latent=1.3069 amtm=135.5556
# step 0040 total=140.5627 mtr=1.1717 latent=1.2258 amtm=139.0845
# step 0060 total=122.3562 mtr=0.4245 latent=0.4424 amtm=121.8210
# step 0080 total=128.8376 mtr=0.4203 latent=0.3556 amtm=128.3284
# step 0100 total=151.6864 mtr=0.2988 latent=0.2378 amtm=151.3282
# step 0120 total=121.4637 mtr=0.3584 latent=0.3123 amtm=121.0273
# step 0140 total=137.8480 mtr=0.2194 latent=0.2670 amtm=137.5618
# step 0160 total=137.1242 mtr=0.2859 latent=0.2266 amtm=136.7817
# step 0180 total=140.2932 mtr=0.2833 latent=0.2087 amtm=139.9577
# step 0200 total=131.6946 mtr=0.1834 latent=0.3786 amtm=131.4165
# step 0220 total=130.9646 mtr=0.3300 latent=0.1689 amtm=130.5923
# step 0240 total=146.2559 mtr=0.3356 latent=0.3943 amtm=145.8217
# step 0260 total=116.8413 mtr=0.2084 latent=0.1028 amtm=116.6072
# step 0280 total=143.1177 mtr=0.2138 latent=0.3195 amtm=142.8240
# step 0300 total=121.3113 mtr=0.2414 latent=0.2891 amtm=120.9976
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/mergedna_ckpts
# !cp checkpoints/ecoli.pt /content/drive/MyDrive/mergedna_ckpts/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
